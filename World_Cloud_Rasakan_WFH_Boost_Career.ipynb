# %% [markdown]
# ### Pendahuluan

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
df = pd.read_excel("rasakan wfh - boost career.xlsx")

# %%
df.head()
# Out:
#                                                Bosan
# 0                                              Capek
# 1       Jenuh dan ketidakpastian dalam bidang apapun
# 2  experience yang berkurang karena terbatasnya m...
# 3  Sejujurnya saya melihat "Blessing in disguise"...
# 4                                           Terpuruk

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Bosan   40 non-null     object
# dtypes: object(1)
# memory usage: 448.0+ bytes

# %% [markdown]
# ### Data Cleaning

# %%
df.isna().sum()
# Out:
# Bosan    0
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40 entries, 0 to 39
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Bosan   40 non-null     object
# dtypes: object(1)
# memory usage: 640.0+ bytes

# %%
df.astype("str")
# Out:
#                                                 Bosan
# 0                                               Capek
# 1        Jenuh dan ketidakpastian dalam bidang apapun
# 2   experience yang berkurang karena terbatasnya m...
# 3   Sejujurnya saya melihat "Blessing in disguise"...
# 4                                            Terpuruk
# 5                   Kesempatan untuk belajar. Terbuka
# 6   Memiliki waktu luang yang lebih banyak tapi te...
# 7   Saya terkadang merasa stres karena tidak memil...
# 8   Bingung, galau, tidak pede apalagi terkait ski...
# 9                 Mudah terdistraksi dan mudah boring
# 10                                             Stress
# 11                          Susah mikir ,overthinking
# 12  Adanya adaptasi kegiatan baru, semua orang dih...
# 13                                        Susah Mikir
# 14                                Stuck dalam bekerja
# 15                                 stress dan bingung
# ...

# %% [markdown]
# ### Data Visualization

# %%
word_cloud = WordCloud(collocations = False, background_color = 'white').generate(str(df))

# %%
plt.imshow(word_cloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# show only 10 words in the wordcloud .
wordcloud = WordCloud(width=480, height=480, max_words=10).generate(str(df))

# %%
# plot the WordCloud image
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %% [markdown]
# ### Kesimpulan

# %% [markdown]
# Berdasarkan visualisasi menggunakan world cloud, dapat disimpulkan bahwa selama wfh peserta menunjukkan sentimen negatif yakni bingung, susah dan dan lain sebagainya
