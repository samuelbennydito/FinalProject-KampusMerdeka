# %% [markdown]
# ### Pendahuluan

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
df = pd.read_excel("berikanmes.xlsx")

# %%
df.head()
# Out:
#                                            Tidak ada
# 0                                      Cv and Resume
# 1  bagaimana cara memotivasi diri agar lebih optimal
# 2                          Informasi mengenai loker
# 3                            Job fair, webinar karir
# 4  Dibuatkan satu wadah untuk informasi lowongan ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Tidak ada  32 non-null     object
# dtypes: object(1)
# memory usage: 384.0+ bytes

# %% [markdown]
# ### Data Cleaning

# %%
df.isna().sum()
# Out:
# Tidak ada    0
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32 entries, 0 to 31
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Tidak ada  32 non-null     object
# dtypes: object(1)
# memory usage: 512.0+ bytes

# %%
df.astype("str")
# Out:
#                                             Tidak ada
# 0                                       Cv and Resume
# 1   bagaimana cara memotivasi diri agar lebih optimal
# 2                           Informasi mengenai loker
# 3                             Job fair, webinar karir
# 4   Dibuatkan satu wadah untuk informasi lowongan ...
# 5   Mungkin bisa di buatkan Group Loker bagi Fresh...
# 6            Ditambah webinar terkait dunia pekerjaan
# 7   Pengetahuan tentang apa yang akan dikerjakan d...
# 8   Mengadakan pelatihan dalan memasuki dunia peke...
# 9                    Informasi seputar lowongan kerja
# 10                          Edukasi seputar kesehatan
# 11                      Tips memasuki dunia pekerjaan
# 12  Menambah webinar yang berhubungan dengan dunia...
# 13                                          Tidak ada
# 14                                          Tidak ada
# 15                                          Tidak ada
# ...

# %% [markdown]
# ### Data Visualization

# %%
word_cloud = WordCloud(collocations = False, background_color = 'white').generate(str(df))

# %%
plt.imshow(word_cloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# show only 10 words in the wordcloud .
wordcloud = WordCloud(width=480, height=480, max_words=10).generate(str(df))

# %%
# plot the WordCloud image
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %% [markdown]
# ### Kesimpulan

# %% [markdown]
# Berdasarkan visualisasi menggunakan world cloud, dapat disimpulkan bahwa MyEduSolve dapat memberikan informasi lowongan pekerjaan kepada peserta untuk menemukan pekerjaannya, yang lebih lanjut dapat dibuatkan satu wadah berisi informasi lowongan pekerjaan tersebut atau melalui notif email. Selain itu, juga dapat diberikan mengenai webinar seperti ini lagi yang bekerja sama dengan mitra lain.
