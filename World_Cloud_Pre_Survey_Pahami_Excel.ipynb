# %% [markdown]
# ### Pendahuluan

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
df = pd.read_excel("opini1.xlsx")

# %%
df.head()
# Out:
#                                  Rumus didalam excel
# 0             Penggunaan rumus dalam microsoft excel
# 1                                  function di excel
# 2                          Memahami rumus agak susah
# 3  1. Masalah beda versi pada MS Excel  2. Permas...
# 4  belum tau semua cara menggunakan rumus di exce...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 288 entries, 0 to 287
# Data columns (total 1 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Rumus didalam excel  288 non-null    object
# dtypes: object(1)
# memory usage: 2.4+ KB

# %% [markdown]
# ### Data Cleaning

# %%
df.isna().sum()
# Out:
# Rumus didalam excel    0
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 288 entries, 0 to 287
# Data columns (total 1 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Rumus didalam excel  288 non-null    object
# dtypes: object(1)
# memory usage: 4.5+ KB

# %%
df.astype("str")
# Out:
#                                    Rumus didalam excel
# 0               Penggunaan rumus dalam microsoft excel
# 1                                    function di excel
# 2                            Memahami rumus agak susah
# 3    1. Masalah beda versi pada MS Excel  2. Permas...
# 4    belum tau semua cara menggunakan rumus di exce...
# ..                                                 ...
# 283                 Menggunakan fitur rumus pada excel
# 284                    Belum familiar dengan fitur2nya
# 285      lupa rumus dan bingung harus pakai rumus apa
# 286  Sering lupa cara menggunakan rumus atau formul...
# 287  Kurang wawasan tentang formula formula yang da...
#
# [288 rows x 1 columns]

# %% [markdown]
# ### Data Visualization

# %%
word_cloud = WordCloud(collocations = False, background_color = 'white').generate(str(df))

# %%
plt.imshow(word_cloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# show only 10 words in the wordcloud .
wordcloud = WordCloud(width=480, height=480, max_words=10).generate(str(df))

# %%
# plot the WordCloud image
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %% [markdown]
# ### Kesimpulan

# %% [markdown]
# Berdasarkan visualisasi menggunakan world cloud, dapat disimpulkan bahwa tantangan yang dihadapi peserta dalam menggunakan microsoft excel adalah terkait dengan penggunaan rumus/formula yang belum mereka pahami. Rekomendasi lebih lanjut yang dapat diberikan kepada MyEduSolve adalah terkait dengan penjelasan rumus, harus diberikan waktu tersendiri sebelum memulai langsung praktek case real dengan tujuan agar pondasi peserta mengenai logika rumus dapat dipahami dan terimplementasi dengan baik. Misalnya pemateri menjelaskan terlebih dahulu bagaimana logika rumus VLOOKUP bekerja dengan diberikan contoh tambahan.
