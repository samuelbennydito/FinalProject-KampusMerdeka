# %% [markdown]
# ### Pendahuluan

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
df = pd.read_excel("selanjutnya - boost career.xlsx")

# %%
df.head()
# Out:
#                        Crafting CV & Interview tips
# 0                                     Review linkedn
# 1  Graphic design, freelancer /Children book illu...
# 2                                  Digital Marketing
# 3                           Tips Linkedin , tips cv
# 4  Emosional burnout terhadap karir secara lebih ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 1 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Crafting CV & Interview tips   15 non-null     object
# dtypes: object(1)
# memory usage: 248.0+ bytes

# %% [markdown]
# ### Data Cleaning

# %%
df.isna().sum()
# Out:
# Crafting CV & Interview tips     0
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 0 to 14
# Data columns (total 1 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Crafting CV & Interview tips   15 non-null     object
# dtypes: object(1)
# memory usage: 240.0+ bytes

# %%
df.astype("str")
# Out:
#                         Crafting CV & Interview tips
# 0                                      Review linkedn
# 1   Graphic design, freelancer /Children book illu...
# 2                                   Digital Marketing
# 3                            Tips Linkedin , tips cv
# 4   Emosional burnout terhadap karir secara lebih ...
# 5                    Negosiasi kompensasi dan benefit
# 6                                        mengenai HRD
# 7                                   Personal Branding
# 8                                           cv review
# 9                    fokus ke seleksi and recruutment
# 10                           tentang CV dan Interview
# 11  mungkin bisa tentang how to build your cv dan ...
# 12                             Passion atau prospect?
# 13  Konsistensi dalam melamar pekerjaan di bidang ...
# 14              design thinking dan critical thinking

# %% [markdown]
# ### Data Visualization

# %%
word_cloud = WordCloud(collocations = False, background_color = 'white').generate(str(df))

# %%
plt.imshow(word_cloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# show only 10 words in the wordcloud .
wordcloud = WordCloud(width=480, height=480, max_words=10).generate(str(df))

# %%
# plot the WordCloud image
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %% [markdown]
# ### Kesimpulan

# %% [markdown]
# Berdasarkan visualisasi menggunakan world cloud, dapat disimpulkan bahwa untuk webinar/workshop/bootcamp selanjutnya, topik yang diinginkan peserta yakni tentang materi, review ataupun tips mengenai CV, interview, linkedn, design atau critical thinking
