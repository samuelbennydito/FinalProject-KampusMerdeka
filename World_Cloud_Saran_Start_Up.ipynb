# %% [markdown]
# ### Pendahuluan

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
df = pd.read_excel("saranopini.xlsx")

# %%
df.head()
# Out:
#                                     Kesalahan teknis
# 0                                        Mengenai IT
# 1  MENGGUANAKAN APPLIKASI LAIN. KARNA MASIH BINGU...
# 2  Tadi ada kendala teknis, seperti audio yg ngga...
# 3                                         Sudah baik
# 4  Beberapa masalah teknis masih dialami, mungkin...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 1 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Kesalahan teknis  32 non-null     object
# dtypes: object(1)
# memory usage: 384.0+ bytes

# %% [markdown]
# ### Data Cleaning

# %%
df.isna().sum()
# Out:
# Kesalahan teknis    0
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32 entries, 0 to 31
# Data columns (total 1 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Kesalahan teknis  32 non-null     object
# dtypes: object(1)
# memory usage: 512.0+ bytes

# %%
df.astype("str")
# Out:
#                                      Kesalahan teknis
# 0                                         Mengenai IT
# 1   MENGGUANAKAN APPLIKASI LAIN. KARNA MASIH BINGU...
# 2   Tadi ada kendala teknis, seperti audio yg ngga...
# 3                                          Sudah baik
# 4   Beberapa masalah teknis masih dialami, mungkin...
# 5             Mungkin bisa di adakan part selanjutnya
# 6                 Persiapan yang matang untuk panitia
# 7   Konten webinar yang disajikan sudah sangat pen...
# 8                                     Dunia pekerjaan
# 9   Adakan materi tentang dunia kerja digital mark...
# 10                                          tidak ada
# 11               Persiapan yang matang untuk pemateri
# 12  Menurut saya sebelum dimulai kegiatan webinar,...
# 13  Tidak ada sudah cukup baik dalam penyampaian m...
# 14         Sudah cukup baik dalam menyampaikan materi
# 15  Sudah cukup baik dalam menyampaikan semua mate...
# ...

# %% [markdown]
# ### Data Visualization

# %%
word_cloud = WordCloud(collocations = False, background_color = 'white').generate(str(df))

# %%
plt.imshow(word_cloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# show only 10 words in the wordcloud .
wordcloud = WordCloud(width=480, height=480, max_words=10).generate(str(df))

# %%
# plot the WordCloud image
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %% [markdown]
# ### Kesimpulan

# %% [markdown]
# Berdasarkan visualisasi menggunakan world cloud, dapat disimpulkan bahwa saran yang diberikan peserta terkait webinar start-up yakni rata rata peserta menganggap webinar yang diberikan sudah baik dan berharap dapat lebih baik lagi ke depannya. Tekait kesalahan teknis, ke-depannya semoga bisa dikurangi. Selain itu, bisa ditambahkan juga lebih banyak contoh contoh.
