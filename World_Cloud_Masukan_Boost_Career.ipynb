# %% [markdown]
# ### Pendahuluan

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
df = pd.read_excel("masukan - boost career.xlsx")

# %%
df.head()
# Out:
#                                     Sudah baik!
# 0                           sudah sangat baikkk
# 1                                  Udah bagus.
# 2  semoga semakin banyak bootcamp gratis kak :)
# 3         Tambahin waktu untk bootcamp nya kak
# 4     Lebih sering mengadakan event seperti ini

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sudah baik!  15 non-null     object
# dtypes: object(1)
# memory usage: 248.0+ bytes

# %% [markdown]
# ### Data Cleaning

# %%
df.isna().sum()
# Out:
# Sudah baik!    0
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 0 to 14
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sudah baik!  15 non-null     object
# dtypes: object(1)
# memory usage: 240.0+ bytes

# %%
df.astype("str")
# Out:
#                                           Sudah baik!
# 0                                 sudah sangat baikkk
# 1                                        Udah bagus.
# 2        semoga semakin banyak bootcamp gratis kak :)
# 3               Tambahin waktu untk bootcamp nya kak
# 4           Lebih sering mengadakan event seperti ini
# 5              Semoga ada materi yang lebih baru lagi
# 6                       Training cukup satu hari saja
# 7                   Kedepannya harus tetep gratiss :(
# 8   bagaimana agar bisa bekerja sama dengan match ...
# 9   mungkin slide dr pemateri dapat dibagikan atau...
# 10                                        Sudah bagus
# 11  mungkin sosialisasi dan promosinya bisa diting...
# 12  Sudah cukup baikk dipadatkan aja utk pembicaranya
# 13                                      Pemateri asik
# 14                            Keep up the good work 👍

# %% [markdown]
# ### Data Visualization

# %%
word_cloud = WordCloud(collocations = False, background_color = 'white').generate(str(df))

# %%
plt.imshow(word_cloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# show only 10 words in the wordcloud .
wordcloud = WordCloud(width=480, height=480, max_words=10).generate(str(df))

# %%
# plot the WordCloud image
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %% [markdown]
# ### Kesimpulan

# %% [markdown]
# Berdasarkan visualisasi menggunakan world cloud, dapat disimpulkan bahwa masukan yang diberikan peserta selama mengikuti 3 days bootcamp menunjukkan sentimen positif. Diluar hal tersebut, peserta menginginkan bootcamp seperti ini gratis, ditambahkan waktunya dengan berbagai materi yang menarik lainnya serta tingkat promosinya ditingkatkan agar lebih banyak peserta yang berpartisipasi
